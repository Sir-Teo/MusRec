# %%
from bing_image_downloader import downloader

music_genre = {"country", "pop", "rock", "jazz", "blues", "classical", "soul"}
for genre in music_genre:
    downloader.download(genre, limit=50,  output_dir='dataset', adult_filter_off=True, force_replace=False, timeout=60, verbose=True)
# Out:
# [%] Downloading Images to /Users/teo/Desktop/MusRec/dataset/jazz
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 18 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://assets.site-static.com/userFiles/182/image/Jazz_Music.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://1.bp.blogspot.com/-EPwsPfi65GQ/UK7o93DMU0I/AAAAAAAAADg/Te-Xy-IJgUg/s1600/jazzchurch.s460x460.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://static.wixstatic.com/media/0b555ae15b5828c77eb1584b9c0d13b1.jpg/v1/fit/w_480%2Ch_567%2Cal_c%2Cq_80/file.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://static.guim.co.uk/sys-images/Observer/Columnist/Columnists/2010/5/11/1273581481358/SPAIN-JAZZ-FESTIVAL-WINTO-006.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://3.bp.blogspot.com/-eXTOw2Q8tAg/WeqBKF3s3II/AAAAAAAAAdc/pt5IsA5F_TEoC0ufetKa5vPSI-AxM-E1ACLcBGAs/w1200-h630-p-k-no-nu/jazz-band.jpg
# [%] File Downloaded !
#
# ...

# %%
import os
music_genre = {"country", "pop", "rock", "jazz", "blues", "classical", "soul"}
for genre in music_genre:
    files_in_dir = os.listdir('dataset/'+genre)
    for file in files_in_dir:
        if not file.endswith('.jpg'):
            os.remove('dataset/'+genre+'/' + file)
# Out:
# Image_22.jpeg
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# Input In [20], in <cell line: 4>()
#       6 for file in files_in_dir:
#       7     print(file)
# ----> 8     im = Image.open('dataset/'+genre+'/'+file)
#       9     im.save('dataset/'+genre+'/'+file.replace('jpg','jpeg'))
#      10     os.remove('dataset/'+genre+'/' + file)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/PIL/Image.py:3008, in open(fp, mode, formats)
#    3006 for message in accept_warnings:
#    3007     warnings.warn(message)
# -> 3008 raise UnidentifiedImageError(
#    3009     "cannot identify image file %r" % (filename if filename else fp)
#    3010 )
#
# UnidentifiedImageError: cannot identify image file 'dataset/soul/Image_22.jpeg'
